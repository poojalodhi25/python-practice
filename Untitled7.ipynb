# %% [markdown]
# <a href="https://colab.research.google.com/github/poojalodhi25/python-practice/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruit_basket=['apple','banana','orange','mango','kiwi']
for i in range(len(fruit_basket)):
  print(i, ":", fruit_basket[i])
# Out:
# 0 : apple
# 1 : banana
# 2 : orange
# 3 : mango
# 4 : kiwi

# %%
fruits=['guava','apple','orange','mango','banana','melon']

for item in fruits:
  print(item)
else:
    print("no more fruits")
# Out:
# guava
# apple
# orange
# mango
# banana
# melon
# no more fruits

# %%
counter =1
while counter <=5:
  print("pooja")
  counter+=1
# Out:
# pooja
# pooja
# pooja
# pooja
# pooja

# %%
str_1 ="pooja lodhi"

for i in str_1:
  print(i)
  print()

  list_1=["welcome", "to","tpoint","tech"]

  for i in list_1:
    print(i)
    print()

tuple_1=("Python", "for" , "Beginners")
for i in tuple_1:
  print(i)
  print()
# Out:
# p
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# o
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# o
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# j
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# a
#
# welcome
#
# to
#
# tpoint
#
# tech
#
#
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# l
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# o
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# d
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# h
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# i
#
# welcome
#
# to
#
# tpoint
#
# tech
#
# Python
#
# for
#
# Beginners
