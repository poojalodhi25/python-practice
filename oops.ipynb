# %% [markdown]
# <a href="https://colab.research.google.com/github/poojalodhi25/python-practice/blob/main/oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=[1,2,3]
print(type(L))
# Out:
# <class 'list'>

# %%
s =[1,2,3]

# %%
L = [1,2,3]

# %%
L =list()
L
# Out:
# []

# %%
class Atm:

    # constructor
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()

    def menu(self):

        user_input = input("""
Hi, how can I help you?

1. Press 1 to create PIN
2. Press 2 to change PIN
3. Press 3 to check balance
4. Press 4 to withdraw
5. Anything else to exit

Enter your choice:
""")

        if user_input == '1':
            self.create_pin()

        elif user_input == '2':
            pass

        elif user_input == '3':
            pass

        elif user_input == '4':
            pass

        else:
            exit()

    def create_pin(self):
        self.pin = input("Enter your PIN: ")
        print("PIN set successfully")

# %%
obj = Atm()
# Out:
# Hi, how can I help you?
#
# 1. Press 1 to create PIN
# 2. Press 2 to change PIN
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# Enter your choice:
# 1
# Enter your PIN: 123
# PIN set successfully

# %%
type(type(obj))
# Out:
# type

# %%
class Atm:

    # constructor
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()

    def menu(self):

        user_input = input("""
Hi, how can I help you?

1. Press 1 to create PIN
2. Press 2 to change PIN
3. Press 3 to check balance
4. Press 4 to withdraw
5. Anything else to exit

Enter your choice:
""")

        if user_input == '1':
            self.create_pin()

        elif user_input == '2':
            self.change_pin()

        elif user_input == '3':
            self.check_balance()

        elif user_input == '4':
            self.withdraw()

        else:
            exit()

    def create_pin(self):

        self.pin = input("Enter your PIN: ")

        self.balance = int(input("Enter your balance: "))

        print("PIN created successfully")
        print("Your balance is:", self.balance)

        self.menu()

    def change_pin(self):

        old_pin = input("Enter your old PIN: ")

        if old_pin == self.pin:

            new_pin = input("Enter your new PIN: ")

            self.pin = new_pin

            print("PIN changed successfully")

            self.menu()

        else:

            print("Wrong PIN, PIN change nahi kar sakte.")

            self.menu()

    def check_balance(self):

        user_pin = input("Enter your PIN: ")

        if user_pin == self.pin:

            print("Your balance is:", self.balance)

            self.menu()

        else:

            print("Wrong PIN")

            self.menu()

    def withdraw(self):

        user_pin = input("Enter your PIN: ")

        if user_pin == self.pin:

            amount = int(input("Enter the amount: "))

            if amount < self.balance:

                self.balance = self.balance - amount

                print("Withdraw successful")
                print("Remaining balance:", self.balance)

            else:

                print("Insufficient balance")

            self.menu()

        else:

            print("Wrong PIN")

            self.menu()

# %%
a = Atm()
# Out:
# Hi, how can I help you?
#
# 1. Press 1 to create PIN
# 2. Press 2 to change PIN
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# Enter your choice:
# 1
# Enter your PIN: 123
# Enter your balance: 10000
# PIN created successfully
# Your balance is: 10000
#
# Hi, how can I help you?
#
# 1. Press 1 to create PIN
# 2. Press 2 to change PIN
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# Enter your choice:
# 2
# Enter your old PIN: 123
# Enter your new PIN: 1234
# PIN changed successfully
#
# Hi, how can I help you?
#
# 1. Press 1 to create PIN
# 2. Press 2 to change PIN
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# Enter your choice:
# 3
# Enter your PIN: 1234
# Your balance is: 10000
#
# Hi, how can I help you?
#
# 1. Press 1 to create PIN
# 2. Press 2 to change PIN
# 3. Press 3 to check balance
# 4. Press 4 to withdraw
# 5. Anything else to exit
#
# Enter your choice:
# 4
# ...
